# %%
# Downloading weights from GCP bucket
! wget https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5

# %% [markdown]
# ### importing basic calculation libraries

# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Initializing classes from file image_search

# %%
from image_searcher import Index,LoadData,SearchImage
image_list = LoadData().from_folder(folder_list = ['demo'])

# %% [markdown]
# ### Strating to process and extract features from data

# %%
Index(image_list).Start()

# %% [markdown]
# # Search to find similar images
# #### Here number_of_images means fist no. of similar images.

# %%
similar_images_name_dic = SearchImage().get_similar_images(image_path=image_list[0],number_of_images=2)

# %%
print(similar_images_name_dic)

# %% [markdown]
# ### Showing similar images

# %%
from PIL import Image

# %%
img1 = similar_images_name_dic[0]
img2 = similar_images_name_dic[1]
img_s1 = Image.open(img1)
img_s2 = Image.open(img2)
img_s1.show()
img_s2.show()
