# %%
# Downloading weights from GCP bucket
# ! wget https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5

# %% [markdown]
# ### importing basic calculation libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Initializing classes from file image_search

# %%
from image_searcher import Index,LoadData,SearchImage
image_list = LoadData().from_folder(folder_list = ['demo2'])
# Out:
# 2022-05-12 15:18:38.022010: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-12 15:18:38.022032: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ### Strating to process and extract features from data

# %%
Index(image_list).Start()
# Out:
# 2022-05-12 15:18:40.527033: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-05-12 15:18:40.527059: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (sacred-pc): /proc/driver/nvidia/version does not exist
# 2022-05-12 15:18:40.527270: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-12 15:18:40.684835: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 411041792 exceeds 10% of free system memory.
# 2022-05-12 15:18:40.851255: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 411041792 exceeds 10% of free system memory.
# 2022-05-12 15:18:40.967586: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 411041792 exceeds 10% of free system memory.
# 2022-05-12 15:18:41.447983: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 411041792 exceeds 10% of free system memory.
# Features are Already saved want To extract again.[yes/no]?
# 100%|██████████| 4/4 [00:01<00:00,  3.76it/s]
# Image Meta Information Saved: [data_files_saved/image_data_features.pkl]
# 4it [00:00, 2586.68it/s]
# Saved the File:[data_files_saved/image_features_vectors.ann]

# %% [markdown]
# # Search to find similar images
# #### Here number_of_images means fist no. of similar images.

# %%
no_of_images = 4

# %%
similar_images_name_dic = SearchImage().get_similar_images(image_path=image_list[0],number_of_images=no_of_images)

# %%
images = list(similar_images_name_dic.values())
print(images)
# Out:
# ['demo2/a.png', 'demo2/keenu2.png', 'demo2/c.JPG', 'demo2/1.JPG']

# %%
import matplotlib.image as mpimg
def mat_image_show(image_list):
    for i in image_list:
        img = mpimg.imread(i)
        imgplot = plt.imshow(img)
        plt.show()

mat_image_show(images)
